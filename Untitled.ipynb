# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %% [markdown]
# what promotes or not promotes students to achive greate GPA and how it influence on their stress level?

# %%
df = pd.read_csv('student_lifestyle_dataset.csv')
df.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# ...

# %%
#general info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Student_ID                       2000 non-null   int64
#  1   Study_Hours_Per_Day              2000 non-null   float64
#  2   Extracurricular_Hours_Per_Day    2000 non-null   float64
#  3   Sleep_Hours_Per_Day              2000 non-null   float64
#  4   Social_Hours_Per_Day             2000 non-null   float64
#  5   Physical_Activity_Hours_Per_Day  2000 non-null   float64
#  6   GPA                              2000 non-null   float64
#  7   Stress_Level                     2000 non-null   object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 125.1+ KB

# %%
#statistical info about dataset
df.describe()
# Out:
#         Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# count  2000.000000          2000.000000                    2000.000000
# mean   1000.500000             7.475800                       1.990100
# std     577.494589             1.423888                       1.155855
# min       1.000000             5.000000                       0.000000
# 25%     500.750000             6.300000                       1.000000
# 50%    1000.500000             7.400000                       2.000000
# 75%    1500.250000             8.700000                       3.000000
# max    2000.000000            10.000000                       4.000000
#
#        Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# count          2000.000000           2000.000000
# mean              7.501250              2.704550
# std               1.460949              1.688514
# min               5.000000              0.000000
# 25%               6.200000              1.200000
# ...

# %%
#find any missing values but have the same info in df.info().['Non-Null Count']
df.isna().sum()
# Out:
# Student_ID                         0
# Study_Hours_Per_Day                0
# Extracurricular_Hours_Per_Day      0
# Sleep_Hours_Per_Day                0
# Social_Hours_Per_Day               0
# Physical_Activity_Hours_Per_Day    0
# GPA                                0
# Stress_Level                       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Student_ID', 'Study_Hours_Per_Day', 'Extracurricular_Hours_Per_Day',
#        'Sleep_Hours_Per_Day', 'Social_Hours_Per_Day',
#        'Physical_Activity_Hours_Per_Day', 'GPA', 'Stress_Level'],
#       dtype='object')

# %%
plt.scatter(df.Study_Hours_Per_Day, df.GPA)
plt.title('Study hours vs GPA')
plt.xlabel('Study hours')
plt.ylabel('GPA')
plt.show()

# %% [markdown]
# There is positive dependence between Study_Hours and GPA. More hours of studing -> greater GPA student achive

# %%
sns.scatterplot(data=df, x='Study_Hours_Per_Day', y='GPA', hue='Stress_Level', hue_order=['Low', 'Moderate', 'High'], alpha=0.7)
plt.show()

# %% [markdown]
# More hours of studing -> greater GPA student achive, but its lead to higher level of stress between students

# %%
plt.scatter(df.Extracurricular_Hours_Per_Day, df.GPA)
plt.title('Extracurricular hours vs GPA')
plt.xlabel('Extracurricular hours')
plt.ylabel('GPA')
plt.show()

# %% [markdown]
# There is positive dependence between Sleep_Hours and GPA. More hours of sleeping -> greater GPA student achive

# %%
sns.scatterplot(data=df, x='Extracurricular_Hours_Per_Day', y='GPA', hue='Stress_Level', hue_order=['Low', 'Moderate', 'High'], alpha=0.7)
plt.show()

# %%
np.corrcoef(df)

# %%
df1 = pd.get_dummies(df['Stress_Level'])
df1.head()
# Out:
#     High    Low  Moderate
# 0  False  False      True
# 1  False   True     False
# 2  False   True     False
# 3  False  False      True
# 4   True  False     False

# %%
df2 = pd.concat([df, df1], axis=1).reindex(df.index)
df2.drop('Stress_Level', axis=1, inplace=True)
df2.info()
#np.corrcoef(df2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Student_ID                       2000 non-null   int64
#  1   Study_Hours_Per_Day              2000 non-null   float64
#  2   Extracurricular_Hours_Per_Day    2000 non-null   float64
#  3   Sleep_Hours_Per_Day              2000 non-null   float64
#  4   Social_Hours_Per_Day             2000 non-null   float64
#  5   Physical_Activity_Hours_Per_Day  2000 non-null   float64
#  6   GPA                              2000 non-null   float64
#  7   High                             2000 non-null   bool
#  8   Low                              2000 non-null   bool
#  9   Moderate                         2000 non-null   bool
# dtypes: bool(3), float64(6), int64(1)
# memory usage: 115.4 KB
